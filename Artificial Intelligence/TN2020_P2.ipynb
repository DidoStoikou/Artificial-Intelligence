# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα ασχοληθείτε και θα εργαστείτε μόνο με το αρχείο movies_metadata.csv.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του αρχείου αυτού, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.).
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata):
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο train_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θα έπρεπε να έχει προταθεί στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να επιστρέφεται 1 ή 0 αν η ταινία θα έπαιρνε βαθμό μεγαλύτερο του 3 ή όχι, δηλαδή αν θα έπρεπε να την είχαμε προτείνει ή όχι.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων (π.χ. 10, 20, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set). Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/gdrive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
import os
os.listdir('/gdrive/My Drive')
path='/gdrive/My Drive/'
# Out:
# Mounted at /gdrive

# %%
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# software-properties-common is already the newest version (0.96.24.32.14).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
#  Comprehensive Prolog implementation with extensive libraries and development tools.   Primarily targetted at teaching, RDF processing and web-related tasks, such as creating web services or analysing web content.
#  More info: https://launchpad.net/~swi-prolog/+archive/ubuntu/stable
# Press [ENTER] to continue or Ctrl-c to cancel adding it.
#
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [41.5 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:13 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:16 http://ppa.launchpad.net/swi-prolog/stable/ubuntu bionic InRelease [15.4 kB]
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,703 kB]
# Get:18 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [872 kB]
# Get:19 http://ppa.launchpad.net/swi-prolog/stable/ubuntu bionic/main amd64 Packages [1,489 B]
# Fetched 2,905 kB in 4s (727 kB/s)
# Reading package lists... Done
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:7 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:12 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:15 http://ppa.launchpad.net/swi-prolog/stable/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   javascript-common libbsd-dev libedit-dev libgmp-dev libgmpxx4ldbl
#   libjs-jquery libncursesw5-dev libossp-uuid16 swi-prolog-nox swi-prolog-x
# Suggested packages:
#   apache2 | lighttpd | httpd gmp-doc libgmp10-doc libmpfr-dev ncurses-doc uuid
#   prolog-el
# The following NEW packages will be installed:
#   javascript-common libbsd-dev libedit-dev libgmp-dev libgmpxx4ldbl
#   libjs-jquery libncursesw5-dev libossp-uuid16 swi-prolog swi-prolog-nox
#   swi-prolog-x
# 0 upgraded, 11 newly installed, 0 to remove and 17 not upgraded.
# Need to get 7,052 kB of archives.
# After this operation, 36.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:2 http://ppa.launchpad.net/swi-prolog/stable/ubuntu bionic/main amd64 swi-prolog-nox amd64 8.2.3-1-ge5584f06e-bionicppa2 [3,946 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libbsd-dev amd64 0.8.7-1ubuntu0.1 [150 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 libedit-dev amd64 3.1-20170329-1 [99.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmpxx4ldbl amd64 2:6.1.2+dfsg-2 [8,964 B]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmp-dev amd64 2:6.1.2+dfsg-2 [316 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libncursesw5-dev amd64 6.1-1ubuntu1.18.04 [199 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libossp-uuid16 amd64 1.6.2-1.5build4 [29.0 kB]
# Get:10 http://ppa.launchpad.net/swi-prolog/stable/ubuntu bionic/main amd64 swi-prolog-x amd64 8.2.3-1-ge5584f06e-bionicppa2 [2,118 kB]
# Get:11 http://ppa.launchpad.net/swi-prolog/stable/ubuntu bionic/main amd64 swi-prolog amd64 8.2.3-1-ge5584f06e-bionicppa2 [27.3 kB]
# Fetched 7,052 kB in 3s (2,324 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 11.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package javascript-common.
# (Reading database ... 145480 files and directories currently installed.)
# Preparing to unpack .../00-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libbsd-dev:amd64.
# Preparing to unpack .../01-libbsd-dev_0.8.7-1ubuntu0.1_amd64.deb ...
# Unpacking libbsd-dev:amd64 (0.8.7-1ubuntu0.1) ...
# Selecting previously unselected package libedit-dev:amd64.
# Preparing to unpack .../02-libedit-dev_3.1-20170329-1_amd64.deb ...
# Unpacking libedit-dev:amd64 (3.1-20170329-1) ...
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# Preparing to unpack .../03-libgmpxx4ldbl_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../04-libgmp-dev_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../05-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libncursesw5-dev:amd64.
# Preparing to unpack .../06-libncursesw5-dev_6.1-1ubuntu1.18.04_amd64.deb ...
# Unpacking libncursesw5-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Selecting previously unselected package libossp-uuid16:amd64.
# Preparing to unpack .../07-libossp-uuid16_1.6.2-1.5build4_amd64.deb ...
# Unpacking libossp-uuid16:amd64 (1.6.2-1.5build4) ...
# Selecting previously unselected package swi-prolog-nox.
# Preparing to unpack .../08-swi-prolog-nox_8.2.3-1-ge5584f06e-bionicppa2_amd64.deb ...
# Unpacking swi-prolog-nox (8.2.3-1-ge5584f06e-bionicppa2) ...
# Selecting previously unselected package swi-prolog-x.
# Preparing to unpack .../09-swi-prolog-x_8.2.3-1-ge5584f06e-bionicppa2_amd64.deb ...
# Unpacking swi-prolog-x (8.2.3-1-ge5584f06e-bionicppa2) ...
# Selecting previously unselected package swi-prolog.
# Preparing to unpack .../10-swi-prolog_8.2.3-1-ge5584f06e-bionicppa2_amd64.deb ...
# Unpacking swi-prolog (8.2.3-1-ge5584f06e-bionicppa2) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up libbsd-dev:amd64 (0.8.7-1ubuntu0.1) ...
# Setting up libossp-uuid16:amd64 (1.6.2-1.5build4) ...
# Setting up libncursesw5-dev:amd64 (6.1-1ubuntu1.18.04) ...
# Setting up libedit-dev:amd64 (3.1-20170329-1) ...
# Setting up javascript-common (11) ...
# Setting up libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Setting up libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Setting up swi-prolog-nox (8.2.3-1-ge5584f06e-bionicppa2) ...
# update-alternatives: using /usr/bin/swipl to provide /usr/bin/prolog (prolog) in auto mode
# Setting up swi-prolog-x (8.2.3-1-ge5584f06e-bionicppa2) ...
# Setting up swi-prolog (8.2.3-1-ge5584f06e-bionicppa2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting pyswip
#   Downloading https://files.pythonhosted.org/packages/dd/b8/9b79319127d48e41542500dea4181ee19758c2710432a397366ac85b7117/pyswip-0.2.10-py2.py3-none-any.whl
# Installing collected packages: pyswip
# Successfully installed pyswip-0.2.10

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
from collections import defaultdict
import pandas as pd
from pyswip import Prolog
import io

all_data = pd.read_csv('movies_metadata.csv')
tags = ['budget', 'genres', 'homepage', 'id', 'plot_keywords', 'language', 'original_title', 'overview', 
        'popularity', 'production_companies', 'production_countries', 'release_date', 'gross', 'duration',
        'spoken_languages', 'status', 'tagline', 'movie_title', 'vote_average', 'num_voted_users', 
        'title_year', 'country', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'Unnamed: 0']


data_dict = all_data.to_dict()
director_dict = {k:v for k,v in data_dict['director_name'].items()}
title_dict = {k:v for k,v in data_dict['original_title'].items()}
genre_dict = {k:v for k,v in data_dict['genres'].items()}
keywords_dict = {k:v for k,v in data_dict['plot_keywords'].items()}
actor_1_dict = {k:v for k,v in data_dict['actor_1_name'].items()}
actor_2_dict = {k:v for k,v in data_dict['actor_2_name'].items()}
actor_3_dict = {k:v for k,v in data_dict['actor_3_name'].items()}
lang_dict = {k:v for k,v in data_dict['language'].items()}

movie_keywords_dict = defaultdict(list) 
director_movie_dict = defaultdict(list)
movie_genre_dict = defaultdict(list)
movie_actors_dict = defaultdict(list)
movie_language_dict = defaultdict(list)

for tag in tags:
    if tag == 'director_name' or tag == 'original_title' or tag == 'genres' or tag == "plot_keywords" or tag == "actor_1_name" or tag == "actor_2_name" or tag == "actor_3_name" or tag == "language":
        pass
    else:
        data_dict.pop(tag)

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %%
for i, dir_val  in enumerate(director_dict.values()):
    for j, tit_val in enumerate(title_dict.values()):
        if i == j and (None != director_movie_dict[dir_val]):
            director_movie_dict[dir_val].append(tit_val)


director_movie_list = []    
director_movie_query = "director('{}', '{}')."


for k,v in director_movie_dict.items():
    for val in director_movie_dict[k]:
        val = clean_text(val)
        try:
            k = clean_text(k)
        except AttributeError:
            pass
        director_movie_query = director_movie_query.format(val, k)
        director_movie_list.append(director_movie_query)
        director_movie_query = "director('{}', '{}')."

# %%
for i, dir_val  in enumerate(title_dict.values()):
    for j, tit_val in enumerate(genre_dict.values()):
        if i == j and (None != movie_genre_dict[dir_val]):
            movie_genre_dict[dir_val].append(tit_val)

for k,v in movie_genre_dict.items():
    if (type(movie_genre_dict[k]) == float):
        del movie_genre_dict[k]   
        
movie_genre_list = []    
movie_genre_query = "genre('{}', '{}')."

for k,v in movie_genre_dict.items():
    try:
        l = v[0].split('|')
        k = clean_text(k)
        movie_genre_query = movie_genre_query.format(k, l)
        movie_genre_list.append(movie_genre_query)
        movie_genre_query = "genre('{}', {})."
    except AttributeError:
        pass

# %%
for i, dir_val  in enumerate(title_dict.values()):
    for j, tit_val in enumerate(keywords_dict.values()):
        if i == j and (None != movie_keywords_dict[dir_val]):
            movie_keywords_dict[dir_val].append(tit_val)


for k,v in movie_keywords_dict.items():
    if (type(movie_keywords_dict[k]) == float):
        del movie_keywords_dict[k]   
        

plot_keywords_list = []    
plot_keywords_query = "keyword('{}', '{}')."


for k,v in movie_keywords_dict.items():
    for val in movie_keywords_dict[k]:
        try:
            for i in val.split('|'):
                k = clean_text(k)
                i = clean_text(i)
                plot_keywords_query = plot_keywords_query.format(k, i)
                plot_keywords_list.append(plot_keywords_query)
                plot_keywords_query = "keyword('{}', '{}')."
        except AttributeError:
            pass

# %%
for i, dir_val  in enumerate(title_dict.values()):
    for j, tit_val in enumerate(lang_dict.values()):
        if i == j and (None != movie_language_dict[dir_val]):
            movie_language_dict[dir_val].append(tit_val)


for k,v in movie_actors_dict.items():
    if (type(movie_actors_dict[k]) == float):
        del movie_actors_dict[k]   


movie_language_list = []    
movie_language_query = "lang('{}', '{}')."


for k,v in movie_language_dict.items():
    for val in movie_language_dict[k]:
        k = clean_text(k)
        movie_language_query = movie_language_query.format(k, val)
        movie_language_list.append(movie_language_query)
        movie_language_query = "lang('{}', '{}')."

# %%
for i, dir_val  in enumerate(title_dict.values()):
    for j, tit_val in enumerate(actor_1_dict.values()):
        if i == j and (None != movie_actors_dict[dir_val]):
            movie_actors_dict[dir_val].append(tit_val)

#add actor_2
for i, dir_val  in enumerate(title_dict.values()):
    for j, tit_val in enumerate(actor_2_dict.values()):
        if i == j and (None != movie_actors_dict[dir_val]):
            movie_actors_dict[dir_val].append(tit_val)
        
#add actor_3
for i, dir_val  in enumerate(title_dict.values()):
    for j, tit_val in enumerate(actor_3_dict.values()):
        if i == j and (None != movie_actors_dict[dir_val]):
            movie_actors_dict[dir_val].append(tit_val)


for k,v in movie_actors_dict.items():
    if (type(movie_actors_dict[k]) == float):
        del movie_actors_dict[k]   
        
movie_actors_list = []    
movie_actors_query = "actors('{}', {})."


for k,v in movie_actors_dict.items():
    k = clean_text(k)
    movie_actors_query = movie_actors_query.format(k, v)
    movie_actors_list.append(movie_actors_query)
    movie_actors_query = "actors('{}', {})."

# %%
#create World
#Ορίζουμε τον κόσμο μας
from pyswip import Prolog
prolog = Prolog()
prolog.consult("db.pl")

def simple_recommender(movie, similarity):
    if similarity == 4:
        q = prolog.query("find_sim_4('" + movie +"',M)")
        ans = []
        for soln in q:
            if soln["M"] not in ans :
                ans.append(soln["M"])
    #   print(ans)
    elif similarity == 3:
        q = prolog.query("find_sim_3('" + movie +"',M)")
        ans = []
        for soln in q:
            if soln["M"] not in ans :
                ans.append(soln["M"])
    #   print(ans)
    elif similarity == 2:
        q = prolog.query("find_sim_2('" + movie +"',M)")
        ans = []
        for soln in q:
            if soln["M"] not in ans :
                ans.append(soln["M"])
    #   print(ans)
    elif similarity == 1:
        q = prolog.query("find_sim_1('" + movie +"',M)")
        ans = []
        for soln in q:
            if soln["M"] not in ans :
                ans.append(soln["M"])
    else:
      q = prolog.query("find_sim_5('" + movie +"',M)")
      ans = []
      for soln in q:
          if soln["M"] not in ans:
            ans.append(soln["M"])
      ans = set(ans)
      
    if  len(list(set(ans))) > 0:
        print(list(set(ans))[:8])
    else :
        print("Try a different recommendation setting")
    return 



def recommend_me(movie):
    for i in range(5,0,-1):
        simple_recommender(movie,i)

# %%
# prolog.assertz('(directed_by(X,Y) :- findall(M,director(M,X),Y))')

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
prolog.assertz('''(find_sim_1(X, Y):-
                                        genre(X, G1),
                                        genre(Y, G1),
                                        X \= Y )''')

# %%
q = prolog.query("find_sim_1('Avatar', Y)")
s = set()
for soln in q:
  m = soln['Y'] 
  if m not in s:
    s.add(soln['Y'])
print(s)
# Out:
# {'Guardians of the Galaxy', 'The Losers', 'Crossroads'}

# %%
def simple_recommender(movie):
    s = set()
    q = prolog.query("find_sim_1('" + movie +"',M)")
    for soln in q:
        m = soln['M'] 
        if m not in s:
            s.add(soln['M'])
    q.close()
    answers = s
    return answers

# %%
list(simple_recommender('Avatar'))[:5]
# Out:
# ['Guardians of the Galaxy', 'The Losers', 'Crossroads']

# %%
#create World
#Ορίζουμε τον κόσμο μας
from pyswip import Prolog
prolog = Prolog()
prolog.consult("db.pl")

def simple_recommender(movie, similarity):
    if similarity == 4:
        q = prolog.query("find_sim_4('" + movie +"',M)")
        ans = []
        for soln in q:
            if soln["M"] not in ans :
                ans.append(soln["M"])
    #   print(ans)
    elif similarity == 3:
        q = prolog.query("find_sim_3('" + movie +"',M)")
        ans = []
        for soln in q:
            if soln["M"] not in ans :
                ans.append(soln["M"])
    #   print(ans)
    elif similarity == 2:
        q = prolog.query("find_sim_2('" + movie +"',M)")
        ans = []
        for soln in q:
            if soln["M"] not in ans :
                ans.append(soln["M"])
    #   print(ans)
    elif similarity == 1:
        q = prolog.query("find_sim_1('" + movie +"',M)")
        ans = []
        for soln in q:
            if soln["M"] not in ans :
                ans.append(soln["M"])
    else:
      q = prolog.query("find_sim_5('" + movie +"',M)")
      ans = []
      for soln in q:
          if soln["M"] not in ans:
            ans.append(soln["M"])
      ans = set(ans)
      
    if  len(list(set(ans))) > 0:
        print(list(set(ans))[:8])
    else :
        print("Try a different recommendation setting")
    return ans



def recommend_me(movie):
    for i in range(5,0,-1):
        simple_recommender(movie,i)

# %%
recommend_me('Avatar')
# Out:
# ['Galaxina', 'Aliens', 'Star Trek Into Darkness', 'Alien³', 'Predators', 'John Carter', 'The Fifth Element', 'Pirates of the Caribbean: On Stranger Tides']
# ['Jason X', 'Alien', 'Battle: Los Angeles', 'Star Trek Into Darkness', 'Cargo', 'Silent Running', 'Jupiter Ascending', 'Green Lantern']
# ['Brother', 'A Hard Days Night', 'Despicable Me', 'The Wild Bunch', 'Standard Operating Procedure', 'Captain America: The First Avenger', 'Don Gato: El inicio de la pandilla', 'Spaced Invaders']
# ['Guardians of the Galaxy']
# ['Guardians of the Galaxy', 'The Losers', 'Crossroads']

# %%
recommend_me('Pirates of the Caribbean: At Worlds End')
# Out:
# ['Shrek the Third', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Nims Island', 'Pirates of the Caribbean: Dead Mans Chest', 'Cutthroat Island', 'In the Heart of the Sea', 'Pirates of the Caribbean: On Stranger Tides']
# ['La sirène du Mississipi', 'Zack and Miri Make a Porno', 'Kung Fu Panda', 'Shrek the Third', 'Nims Island', 'Captain Phillips', 'In the Heart of the Sea', 'The Bounty']
# ['Red Riding Hood', 'Finding Nemo', 'Monsters University', 'Basquiat', 'You, Me and Dupree', 'Guardians of the Galaxy', 'Austin Powers: International Man of Mystery', 'Gentlemen Broncos']
# ['Pirates of the Caribbean: Dead Mans Chest']
# ['Ronin', 'The Three Musketeers', 'Pirates of the Caribbean: Dead Mans Chest']

# %%
recommend_me('Interstellar')
# Out:
# ['Frequency', 'Oblivion', 'Autómata', 'I, Robot', 'Terminator 3: Rise of the Machines', 'The Astronauts Wife', 'Space Cowboys', 'The Martian']
# ['Oblivion', 'Guardians of the Galaxy', 'Alien: Resurrection', 'Dear Frankie', 'Dune', 'Dawn of the Planet of the Apes', 'Escape from Planet Earth', 'The Matrix Reloaded']
# ['Finding Nemo', 'A Million Ways to Die in the West', 'Ta Ra Rum Pum', 'Dune', 'Virtuosity', 'Dawn of the Planet of the Apes', 'World Trade Center', 'Hugo']
# ['The Dark Knight', 'The Martian']
# ['The Martian']

# %%
recommend_me('The Avengers')
# Out:
# ['Iron Man', '4: Rise of the Silver Surfer', 'Deadpool', 'Superman', 'Guardians of the Galaxy', 'Superman II', 'X-Men Origins: Wolverine', 'Iron Man 3']
# ['Red Riding Hood', 'Finding Nemo', 'Austin Powers: International Man of Mystery', 'Guardians of the Galaxy', 'Gentlemen Broncos', 'Blade: Trinity', 'Kill Bill: Vol. 2', 'The Wolverine']
# ['Finding Nemo', 'Hotel for Dogs', 'The Invasion', 'Invictus', 'Ta Ra Rum Pum', 'Gremlins 2: The New Batch', 'Jeepers Creepers', 'Big Mommas: Like Father, Like Son']
# ['Not Another Teen Movie', 'Avengers: Age of Ultron', 'Margaret']
# ['Now You See Me 2', 'Avengers: Age of Ultron']

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score


rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i + 1:i + 1 for i in range(5)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, start=0, end = -1, movie_score = {}):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train,
    ενώ παράλληλα μπορούμε να αρχικοποιήσουμε και το movie_score το οποίο αποθηκεύονται τα score κάθε ταινίας.
    Έτσι αν έχουμε κάνει train τον recommender μας για τις πρώτες 10 ταινίες, μπορούμε να συνεχίσουμε για τις 
    υπόλοιπες χωρίς κάθε φορά να ξανά-διαμορφώνουμε το score για αυτές. Αυτό θα σας βοηθήσει στην εκτέλεση και χρονικά όταν ελέγχετε την 
    απόδοση σε υποσύνολα των ratings π.χ. πρώτες 10 ταινίες έπειτα τις επόμενες 20 κ.ο.κ.
    """
    # movie_score = {i:0 for i in title_dict}

    if end == -1:
        end = len(ratings)

    ratings = ratings.iloc[range(start, end)]
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')
        
        for similarity in range(1,6):
            similar_movies = simple_recommender(movie,similarity)

            for similar_movie in similar_movies:
                if similar_movie not in movie_score:
                    movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[similarity]
                else:
                    movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[similarity] #το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


#αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict
#έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %%
train_ratings = pd.read_csv("train_ratings.csv")
test_ratings = pd.read_csv("test_ratings.csv")

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 0, 10)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Killing Them Softly', 'Divergent', 'The Great Gatsby', 'Ella Enchanted', 'Home Alone', 'The Bourne Supremacy', 'One for the Money']
# ['Forrest Gump', 'Diary of a Wimpy Kid', 'Fast Times at Ridgemont High', 'To Kill a Mockingbird', 'Silver Linings Playbook', 'Finding Neverland', 'Brooklyn', 'On the Road']
# ['Fast Times at Ridgemont High']
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Train', 'Jaws: The Revenge', 'Harry Potter and the Order of the Phoenix', 'Das Boot', 'The Sound of Music', 'Unbroken', 'Atonement', 'The Longest Day']
# ['Tora! Tora! Tora!', 'The English Patient', 'Flags of Our Fathers', 'Der Untergang', '南京!南京!']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['I Love You Phillip Morris', 'Brooklyn', 'Romeo + Juliet']
# Try a different recommendation setting
# ['The Duchess', 'Mo Better Blues', 'Pitch Perfect 2', 'Riding in Cars with Boys', 'Southland Tales', 'Black Nativity', 'The Help', 'Self/less']
# ['Across the Universe', 'Les Choristes', 'High School Musical 2', 'American Dreamz', 'High School Musical', 'Woodstock', 'Mr. Hollands Opus', 'History of the World: Part I']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Pacific Rim']
# ['Austin Powers: The Spy Who Shagged Me', 'Zack and Miri Make a Porno', 'The Animal', 'The Avengers', 'Pitch Perfect 2', 'VeggieTales: The Pirates Who Dont Do Anything', 'Mars Needs Moms', 'Act of Valor']
# ['Identity Thief']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Killing Them Softly', 'Håkon Håkonsen', 'Divergent', 'Oscar and Lucinda', 'The Great Gatsby', 'Ella Enchanted', 'Brother']
# ['The Last Samurai', 'Girl, Interrupted', 'The Great Escape', 'Anna Karenina', '21 Grams', 'Lost in Translation', 'Magnolia', 'In Dreams']
# ['The Last Samurai']
# ['Disclosure']
# Try a different recommendation setting
# ['Romeo Is Bleeding', 'Session 9', 'Underclassman', 'Jack Reacher', 'Brooklyns Finest', 'Beverly Hills Cop', 'The Story of Us', 'Money Monster']
# ['Copycat', 'The Devils Double', 'Romeo Is Bleeding', 'The Jacket', 'First Blood', 'xXx: State of the Union']
# ['Copycat']
# ['The Dead Girl']
# Try a different recommendation setting
# ['Jaws: The Revenge', 'Austin Powers: The Spy Who Shagged Me', 'Harry Potter and the Order of the Phoenix', 'Letters from Iwo Jima', 'The Duchess', 'What Dreams May Come', 'Home Alone', 'Darkness']
# ['Oliver Twist', 'Mystic River', 'What Dreams May Come', 'Top Gun', 'Ice Age', 'Reign Over Me', 'The Devils Advocate', 'Gremlins 2: The New Batch']
# ['Finding Neverland', 'Mystic River']
# ['The Mummy: Tomb of the Dragon Emperor']
# ['The Art of Getting By']
# ['The Loved Ones', 'Julija in Alfa Romeo', 'Sleepover', 'Shes the Man', 'Juno', 'Y tu mamá también', 'Now Is Good', 'Disturbing Behavior']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Music and Lyrics', 'Two Weeks Notice', 'Maurice', 'Florence Foster Jenkins', 'Bridget Jones: The Edge of Reason']
# ['102 Dalmatians', 'Bridget Jones: The Edge of Reason']
# ['Paris, je taime', 'Glitter', 'A Hard Days Night', 'Toy Story', 'Conspiracy Theory', 'Born on the Fourth of July', 'The Wild Bunch', 'Charlie and the Chocolate Factory']
# ['Morning Glory', 'Boys and Girls', 'Finding Neverland', 'The Muppet Movie', 'A Mighty Heart', 'Josie and the Pussycats', 'Trainspotting', 'Something Borrowed']
# ['Finding Neverland', 'Basquiat']
#
# {'precision': 0.5263157894736842, 'recall': 0.2777777777777778, 'f1': 0.36363636363636365}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10, 20, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Try a different recommendation setting
# Try a different recommendation setting
# ['Pitch Perfect 2', 'Despicable Me', 'Chappie', 'Super Troopers', 'Saving Silverman', 'Oceans', 'Anchorman: The Legend of Ron Burgundy', 'Old Dogs']
# ['Captain America: Civil War', 'The Island', 'Pacific Rim', 'The Dark Knight', 'Mr. Peabody & Sherman', 'Transformers: Age of Extinction', 'The Muppets', 'Madagascar: Escape 2 Africa']
# ['Transformers', 'Transformers: Age of Extinction']
# ['American Dreamz']
# ['Finding Nemo']
# ['The Train', 'The Sorcerers Apprentice', 'Austin Powers: The Spy Who Shagged Me', 'Zack and Miri Make a Porno', 'Cloverfield', 'The Avengers', 'The Animal', 'Home Alone']
# ['Cloverfield', 'Bridget Jones: The Edge of Reason']
# Try a different recommendation setting
# ['Her', 'The 51st State', 'Lovely & Amazing', 'Don Jon', 'The Glimmer Man', 'The Spirit', 'Rise of the Planet of the Apes', 'In Good Company']
# ['Troy', 'Lost in Translation', 'Her']
# ['The Canyons', 'Swept Away', 'The Sorcerers Apprentice', 'The Duchess', 'Julija in Alfa Romeo', 'The Rules of Attraction', 'Don Juan DeMarco', 'Just Go with It']
# ['Scoop', 'The Piano', 'Notes on a Scandal', 'Miss Julie', 'Savage Grace', 'The Curse of the Jade Scorpion', 'Shooting Fish', 'Tootsie']
# ['Shooting Fish', 'The Oh in Ohio']
# ['National Treasure', 'The Spirit']
# Try a different recommendation setting
# ['Austin Powers: The Spy Who Shagged Me', 'Zack and Miri Make a Porno', 'Sin City: A Dame to Kill For', 'City of Ember', 'Divergent', 'Splice', 'Cloverfield', 'Spider-Man 2']
# ['Dawn of the Planet of the Apes', 'The Great Escape', 'Maze Runner: The Scorch Trials', 'Armageddon', 'The Rock', 'Never Let Me Go', 'Fortress', 'Transformers']
# ['Moon']
# ['South Park: Bigger, Longer & Uncut']
# Try a different recommendation setting
# ['The Train', 'The Count of Monte Cristo', 'Scarface', 'Harry Potter and the Order of the Phoenix', 'Nims Island', 'Swept Away', 'Paris, je taime', 'Rendition']
# ['The Train', 'Un long dimanche de fiançailles', 'Syriana', 'Rendition', 'The Spy Who Loved Me', 'A Most Violent Year', 'Sphinx', 'The Da Vinci Code']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Watchmen', 'The Sorcerers Apprentice', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Half-Blood Prince', 'Ella Enchanted', 'Darkness', 'Just Visiting']
# ['Aladdin', 'The Sorcerers Apprentice', 'Harry Potter and the Order of the Phoenix', 'Mulan', 'Conan the Destroyer', 'La Marche de lempereur', 'Harry Potter and the Chamber of Secrets', 'Shrek']
# ['The Sorcerers Apprentice', 'Your Highness', 'Warcraft']
# ['Hanging Up', 'And So It Goes', 'The Family Stone', 'Town & Country', 'Sleeper', 'Annie Hall']
# ['Hanging Up', 'Love the Coopers', 'North Country']
# ['The Cavemans Valentine', 'Butterfly Girl', 'Nims Island', 'Oscar and Lucinda', 'Riding in Cars with Boys', 'Pitch Perfect 2', 'Freakonomics', 'Water']
# ['An Education', 'Lost in Translation']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Zack and Miri Make a Porno', 'The Sorcerers Apprentice', 'Cloverfield', 'Spider-Man 2', 'The Green Hornet', 'Cinderella Man', 'Self/less', 'Now Is Good']
# ['Ali', 'The Hurricane', 'Never Back Down', 'Rocky', 'Abduction', 'The Notebook', 'Cinderella Man', 'Big Fish']
# ['Rocky', 'Cinderella Man', 'Raging Bull', 'Million Dollar Baby']
# ['Salt']
# Try a different recommendation setting
# ['Pitch Perfect 2', 'Repo Men', 'Freakonomics', 'Despicable Me', 'Super Troopers', 'Saving Silverman', 'I Hope They Serve Beer in Hell', 'Captain America: The First Avenger']
# ['Austin Powers: The Spy Who Shagged Me', 'Zack and Miri Make a Porno', 'The Avengers', 'VeggieTales: The Pirates Who Dont Do Anything', 'Spider-Man 2', 'The Wolverine', 'Superman II', 'Super Troopers']
# ['Deadpool', 'The Avengers', 'X-Men: First Class', 'X-Men: Apocalypse', 'Captain America: Civil War', 'Iron Man 3', 'X-Men', 'Slither']
# ['Leatherheads', 'One True Thing', 'The Illusionist', 'Saving Mr. Banks', 'Miss Potter']
# ['Saving Mr. Banks']
# ['The Sorcerers Apprentice', 'Lola rennt', 'The Quiet', 'Nims Island', 'Touching the Void', '葉問3', 'The Green Hornet', 'The Fifth Estate']
# ['Ali', 'Race', 'Eddie the Eagle', 'Against the Ropes', 'Soul Surfer', 'Raging Bull', 'Radio', 'The Wrestler']
# ['Ali', 'The Hurricane', 'Rocky Balboa', 'Raging Bull', 'Rocky', 'Million Dollar Baby']
#
# {'precision': 0.47368421052631576, 'recall': 0.375, 'f1': 0.4186046511627907}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 20, 30, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Try a different recommendation setting
# Try a different recommendation setting
# ['Austin Powers: The Spy Who Shagged Me', 'The Sorcerers Apprentice', 'Bait', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Half-Blood Prince', 'Lola rennt', 'Men in Black 3', 'Highlander']
# ['The Sorcerers Apprentice', 'Harry Potter and the Order of the Phoenix', 'Monty Python and the Holy Grail', 'Southland Tales', 'Les Visiteurs 2 : Les Couloirs du temps', 'Dune', 'Hotel Transylvania 2', 'Død snø']
# ['Les Visiteurs 2 : Les Couloirs du temps', 'Black Knight', 'Hotel Transylvania', 'Hotel Transylvania 2', 'Southland Tales']
# ['The Good German', 'Cinderella', 'Oscar and Lucinda']
# Try a different recommendation setting
# ['The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Oscar and Lucinda', 'Freakonomics', 'Southland Tales', 'Conspiracy Theory', 'The Wild Bunch', 'The Dead Zone', 'Y tu mamá también']
# ['The Canyons', 'Julija in Alfa Romeo', 'Your Sisters Sister', 'The Great Gatsby', 'Conspiracy Theory', 'Just Go with It', 'Network', 'Charlie and the Chocolate Factory']
# ['The Canyons', 'Forrest Gump', 'Just Looking', 'Julija in Alfa Romeo', 'The Great Gatsby', 'EuroTrip', 'The Big Bounce', 'The Hotel New Hampshire']
# ['Blue Streak']
# Try a different recommendation setting
# ['Jaws: The Revenge', 'Bait', 'The Avengers', 'Analyze This', 'What Women Want', 'Payback', 'Highlander', 'Conspiracy Theory']
# ['Legal Eagles']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Repo Men', 'Star Trek IV: The Voyage Home', 'Super Troopers', 'Star Wars: Episode I - The Phantom Menace', 'I Hope They Serve Beer in Hell', 'Captain America: The First Avenger', 'The Specials', 'Madea Goes to Jail']
# ['Austin Powers: The Spy Who Shagged Me', 'Watchmen', 'Deadpool', 'Man of Steel', 'The Avengers', 'Captain America: Civil War', 'Iron Man 3', 'X-Men: Apocalypse']
# ['Deadpool', 'Man of Steel', 'The Avengers', 'Captain America: Civil War', 'Iron Man 3', 'X-Men: Apocalypse', 'Superman III', 'Thor']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Mo Better Blues', 'Black Nativity', 'Aladdin', 'The Sound of Music', 'Les Choristes', 'The Soloist', 'The Boat That Rocked', '42nd Street']
# ['Hannah Montana: The Movie']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Secretary', 'Lola rennt', 'Payback', 'Dantes Peak', 'キュア', 'The Good Girl', 'Escobar: Paradise Lost', 'Gosford Park']
# ['The Way of the Gun', 'Secretary', 'The Grand Budapest Hotel', 'Kill List', 'Kingdom of the Spiders', 'Bottle Rocket', 'Lolita', 'Party Monster']
# Try a different recommendation setting
# ['Duplex', 'Firestarter', '50 First Dates', 'Charlie Wilsons War', 'Secret in Their Eyes', 'Lucky You']
# Try a different recommendation setting
# ['葉問3', 'The Fifth Estate', 'Against the Ropes', 'Cinderella Man', 'Joan of Arc', 'A Dangerous Method', 'People I Know', 'Duplex']
# ['Leatherheads']
# Try a different recommendation setting
# ['A Passage to India', 'The Bridge on the River Kwai', 'Waterloo']
# Try a different recommendation setting
# ['Hross í oss', 'The Wolverine', 'Born on the Fourth of July', 'Flicka', 'The Hunger Games: Mockingjay - Part 1', 'Aladdin', 'Unbroken', 'Tank Girl']
# ['War Horse', 'Gods of Egypt', 'Gandhi', 'The 13th Warrior', 'The Bridge on the River Kwai', 'A Passage to India']
# Try a different recommendation setting
# ['Scoop', 'As Good as It Gets', 'The Sessions']
# Try a different recommendation setting
# ['The Quiet', 'Travellers and Magicians', 'Were No Angels', 'Freakonomics', 'The Rules of Attraction', 'Drive', 'The Poker House', 'But Im a Cheerleader']
# ['Thumbsucker', 'Match Point']
# Try a different recommendation setting
# ['Blade: Trinity', 'Blade II', 'Prisoners', 'Ballistic: Ecks vs. Sever', 'Auto Focus', 'Body Double']
# Try a different recommendation setting
# ['Killing Them Softly', 'Lola rennt', 'The Avengers', 'Analyze This', 'Highlander', 'Conspiracy Theory', 'Superman II', 'Sorcerer']
# ['The Way of the Gun', 'Sexy Beast', 'The Hudsucker Proxy', '54', 'The Immigrant', 'Party Monster', 'Live and Let Die', '15 Minutes']
# Try a different recommendation setting
#
# {'precision': 0.4603174603174603, 'recall': 0.4027777777777778, 'f1': 0.4296296296296296}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30, 50, movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Raven', 'Hostel', 'Funny Games', 'A Most Violent Year', 'DragonHeart', 'The Silence of the Lambs', 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'The Collection']
# ['The Dark Hours', 'The Silence of the Lambs', 'Friday the 13th Part VIII: Jason Takes Manhattan', 'Malevolence', 'Red Dragon', 'Black Christmas', 'Untraceable', 'The Texas Chainsaw Massacre: The Beginning']
# ['The Silence of the Lambs']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Nims Island', 'Were No Angels', 'Freakonomics', 'Drive', 'Conspiracy Theory', 'But Im a Cheerleader', 'The Dead Zone', 'My Super Ex-Girlfriend']
# ['Factory Girl', 'Just Looking', 'Transamerica', 'Metropolitan', 'Blue Jasmine', 'Shakespeare in Love', 'Party Monster', 'Veronika Decides to Die']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['A Time to Kill', 'Mirror Mirror', 'The Train', 'Malcolm X', 'The Bad Lieutenant: Port of Call - New Orleans', 'Pulp Fiction', 'Rendition', 'Brother']
# ['The Hunted', 'Training Day', 'Tropa de Elite', 'Traffic', 'Layer Cake', 'Brooklyns Finest', 'City Hall', 'Straight Outta Compton']
# Try a different recommendation setting
# ['Alvin and the Chipmunks: Chipwrecked', 'Alvin and the Chipmunks: The Squeakquel', 'Rio', 'Wreck-It Ralph']
# ['Wreck-It Ralph', 'The Three Stooges', 'Alvin and the Chipmunks: Chipwrecked', 'Alvin and the Chipmunks: The Squeakquel', 'Rio']
# ['Nims Island', 'Pitch Perfect 2', 'Despicable Me', 'The Wild Bunch', 'Super Troopers', 'Saving Silverman', 'Dumb and Dumber To', 'Prom']
# ['Charlottes Web', 'Pitch Perfect 2', 'Cars', 'August Rush', 'Michael Jacksons This Is It', 'Muppets from Space', 'The Jungle Book', 'Garfield: A Tail of Two Kitties']
# ['Alvin and the Chipmunks: The Road Chip', 'Shine a Light', 'Walk Hard: The Dewey Cox Story', 'Josie and the Pussycats', 'Michael Jacksons This Is It', 'Mr. Peabody & Sherman']
# ['Harry Potter and the Order of the Phoenix', 'Harry Potter and the Half-Blood Prince', 'Harry Potter and the Chamber of Secrets', 'Harry Potter and the Prisoner of Azkaban', 'The Tale of Despereaux', 'Harry Potter and the Goblet of Fire']
# ['Harry Potter and the Order of the Phoenix', 'Harry Potter and the Half-Blood Prince', 'Harry Potter and the Chamber of Secrets', 'Harry Potter and the Prisoner of Azkaban', 'Harry Potter and the Goblet of Fire']
# ['The Chronicles of Narnia: The Voyage of the Dawn Treader', 'The Sorcerers Apprentice', 'The Quiet', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Half-Blood Prince', 'Divergent', 'Ella Enchanted', 'Army of Darkness']
# ['The Chronicles of Narnia: The Voyage of the Dawn Treader', 'The Sorcerers Apprentice', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Half-Blood Prince', 'Hocus Pocus', 'Ella Enchanted', 'Oz: The Great and Powerful', 'Dune']
# ['Harry Potter and the Prisoner of Azkaban', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Half-Blood Prince', 'Seventh Son', 'Harry Potter and the Chamber of Secrets', 'Harry Potter and the Goblet of Fire']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Sin City: A Dame to Kill For', 'Romeo Is Bleeding', 'The Vow', 'The Bourne Supremacy', 'Southland Tales', 'Conspiracy Theory', 'Funny Games', 'Fatal Attraction']
# ['Topaz', 'The I Inside', 'The Bourne Supremacy', 'Frenzy', 'Mulholland Drive']
# Try a different recommendation setting
# ['Shes the One']
# Try a different recommendation setting
# ['The Cavemans Valentine', 'Butterfly Girl', 'Nims Island', 'Oscar and Lucinda', 'Riding in Cars with Boys', 'Pitch Perfect 2', 'Freakonomics', 'Water']
# ['Under the Tuscan Sun', 'The Piano', 'The Last Five Years', 'جدایی نادر از سیمین', 'Aroused', 'Walking and Talking', 'Lovely & Amazing', 'Divine Secrets of the Ya-Ya Sisterhood']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Canyons', 'Lola rennt', 'Julija in Alfa Romeo', 'The Avengers', 'Analyze This', 'The Green Hornet', 'Anomalisa', 'Payback']
# ['We Own the Night', 'Just Looking', 'Boogie Nights', 'Buffalo Soldiers', 'Payback', 'The Immigrant', 'The Doors', 'Sea of Love']
# ['The Oh in Ohio', 'Factory Girl', 'Party Monster', 'Basquiat']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Austin Powers: The Spy Who Shagged Me', 'Sin City: A Dame to Kill For', 'City of Ember', 'Divergent', 'Dawn of the Planet of the Apes', 'Repo Men', 'Analyze This', 'Freaky Friday']
# ['I Am Legend', 'Transcendence', 'Interstellar', 'Terminator Salvation', 'The Terminator', 'Men in Black II', 'Fortress', 'Autómata']
# ['I, Robot', 'The Matrix', 'Terminator Genisys', 'Interstellar', 'Blade Runner', 'Terminator Salvation', 'The Matrix Revolutions', 'The Terminator']
# ['Chéri', 'Charlie Bartlett', 'The Family Stone', 'The Matador', 'The Weather Man', 'Georgia Rule']
# Try a different recommendation setting
# ['Reality Show', 'The Family Stone', 'Shall We Dance?', 'Good bye, Lenin!', 'Americas Sweethearts', 'Southland Tales', 'The Lucky One', 'The Shaggy Dog']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Madagascar 3: Europes Most Wanted', 'Madagascar: Escape 2 Africa']
# ['Madagascar: Escape 2 Africa']
# ['Meet the Spartans', 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'Penguins of Madagascar', 'La Marche de lempereur', 'George of the Jungle', 'Roar', 'The Ghost and the Darkness', 'Duma']
# ['Roar', 'Madagascar: Escape 2 Africa']
# ['Madagascar: Escape 2 Africa']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Dawn of the Planet of the Apes', 'Conspiracy Theory', 'The Trouble with Harry', 'DragonHeart', 'The Fugitive', 'The Long Kiss Goodnight', 'The Jungle Book', 'Disturbing Behavior']
# ['Rambo: First Blood Part II', 'The Edge', 'Over the Hedge', 'Dr. Dolittle 2', 'Into the Grizzly Maze', 'The Italian Job', 'Knight and Day', 'Trolljegeren']
# ['Trolljegeren', 'Into the Grizzly Maze', 'The Revenant']
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Animal', 'Ella Enchanted', 'Spider-Man 2', 'Darkness', 'Dawn of the Planet of the Apes', 'As Above, So Below', 'Brooklyns Finest', 'Dantes Peak']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Train', 'The Addams Family', 'Paris, je taime', 'Dracula 2000', 'Bled', 'As Above, So Below', 'The League of Extraordinary Gentlemen', 'Armageddon']
# ['The Twilight Saga: New Moon', 'Underworld: Evolution', 'Blade', 'Dracula', 'Queen of the Damned', 'Underworld: Rise of the Lycans', 'The Twilight Saga: Eclipse', 'Dracula 2000']
# ['Dracula', 'Blade', 'Queen of the Damned', 'The Twilight Saga: Eclipse', 'Dracula 2000', 'Underworld', 'Dracula Untold', 'The Little Vampire']
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Cavemans Valentine', 'Håkon Håkonsen', 'Butterfly Girl', 'Nims Island', 'Oscar and Lucinda', 'Were No Angels', 'Riding in Cars with Boys', 'Pitch Perfect 2']
# ['The Chumscrubber', '200 Cigarettes', 'The Quiet', 'Brick Lane', 'Sherrybaby', 'Freakonomics', 'Igby Goes Down', 'The Ballad of Jack and Rose']
# ['The Savages']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Killing Them Softly', 'Sin City: A Dame to Kill For', 'The Loved Ones', 'Julija in Alfa Romeo', 'Sleepover', 'In Cold Blood', 'Southland Tales', 'Conspiracy Theory']
# ['I Still Know What You Did Last Summer', 'Very Bad Things', 'Carrie', 'Disturbing Behavior', 'Raymond Did It', 'Kick-Ass', 'EuroTrip', 'House of Wax']
# ['Cabin Fever']
# ['Bill & Teds Excellent Adventure']
# ['Bill & Teds Excellent Adventure']
# ['Jaws: The Revenge', 'Austin Powers: The Spy Who Shagged Me', 'Harry Potter and the Order of the Phoenix', 'Letters from Iwo Jima', 'What Dreams May Come', 'Army of Darkness', 'Men in Black 3', 'Dead Like Me: Life After Death']
# ['What Dreams May Come', 'Army of Darkness', 'Southland Tales', 'The Sticky Fingers of Time', 'Click', 'Premonition', 'City of Angels', 'Autómata']
# ['Bill & Teds Excellent Adventure']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Austin Powers: The Spy Who Shagged Me', 'Sin City: A Dame to Kill For', 'City of Ember', 'Divergent', 'Romeo Is Bleeding', 'VeggieTales: The Pirates Who Dont Do Anything', 'Rendition', 'The Prisoner of Zenda']
# ['Babylon A.D.', 'District 9', 'Die Hard', 'Escape from L.A.', 'Live Free or Die Hard', 'RoboCop 3', 'Blade Runner', 'The Matrix Revolutions']
# ['アキラ', 'Escape from L.A.']
#
# {'precision': 0.42857142857142855, 'recall': 0.5, 'f1': 0.4615384615384615}

# %%
movie_score = train_recommender(train_ratings, rating_weights, score_weights,start = 50, movie_score= movie_score)
real, pred = predict_example(test_ratings, movie_score)
print (get_metrics(real, pred))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ['Fury', 'World Trade Center']
# ['Fury']
# ['Rendition', 'The Fifth Estate', 'Southland Tales', 'Sky Captain and the World of Tomorrow', 'The Hunger Games: Mockingjay - Part 1', 'The Dark Knight Rises', 'Unbroken', 'Henry V']
# ['All the Kings Men', 'Wag the Dog', 'Die Hard', 'Snow Falling on Cedars', 'The Kite Runner', 'Dark City', 'Max', 'Rendition']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Slackers', 'Igby Goes Down', 'Me and Orson Welles', 'Romeo + Juliet']
# Try a different recommendation setting
# ['Employee of the Month', 'Me and Orson Welles', 'Igby Goes Down', 'Romeo + Juliet', 'Slackers', 'Clerks', 'Holy Man', 'Human Traffic']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Notting Hill']
# Try a different recommendation setting
# ['Zack and Miri Make a Porno', 'But Im a Cheerleader', 'Y tu mamá también', 'Pink Flamingos', 'Beginners', 'Imagine Me & You', 'The Skeleton Twins', 'Weekend']
# ['D.E.B.S.', 'A Room with a View', 'Jefferson in Paris', 'Y tu mamá también', 'Beginners', 'Weekend', 'Latter Days', 'Chicken Tikka Masala']
# ['In & Out', 'Mambo Italiano', 'Saved!', 'Sommersturm']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Full Frontal', 'The Mask']
# Try a different recommendation setting
# ['The Sorcerers Apprentice', 'Harry Potter and the Order of the Phoenix', 'Harry Potter and the Half-Blood Prince', 'Army of Darkness', 'Space Chimps', 'The Last of the Mohicans', 'Circumstance', 'Salton Sea']
# ['The English Patient', 'Transamerica', 'Så som i himmelen']
# ['Transamerica']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Charlottes Web', 'Dragonball Evolution', 'Dougs 1st Movie', 'The Great Escape', 'The Ballad of Jack and Rose', 'The Kids Are All Right', 'Just Go with It', 'How the Grinch Stole Christmas']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Shark Tale']
# ['Nacho Libre', 'Road House', 'Casino Royale', 'Owning Mahowny', 'Lola rennt', 'The Railway Man', '2 Guns', 'The Hustler']
# ['Amores perros', 'GoodFellas', 'Casino']
# Try a different recommendation setting
# ['Whats Eating Gilbert Grape']
# Try a different recommendation setting
# ['The Sorcerers Apprentice', 'Swept Away', 'Håkon Håkonsen', 'Nims Island', 'Cloverfield', 'Julija in Alfa Romeo', 'The Great Gatsby', 'Dawn of the Planet of the Apes']
# ['Pirates of the Caribbean: At Worlds End', 'Cloverfield', 'Jurassic World', 'Star Trek Into Darkness', 'Captain America: Civil War', 'The Immigrant', 'I, Frankenstein', 'Poseidon']
# ['Pompeii']
# ['The Color Purple']
# ['The Color Purple', 'Finding Nemo']
# ['Austin Powers: The Spy Who Shagged Me', 'Zack and Miri Make a Porno', 'The Avengers', 'Pitch Perfect 2', 'VeggieTales: The Pirates Who Dont Do Anything', 'Mars Needs Moms', 'Act of Valor', 'Despicable Me']
# ['Year One']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Austin Powers: The Spy Who Shagged Me', 'Lara Croft Tomb Raider: The Cradle of Life', 'The Train', 'American History X', 'Vertical Limit', 'As Above, So Below', 'The League of Extraordinary Gentlemen', 'Armageddon']
# ['National Treasure', 'Lara Croft Tomb Raider: The Cradle of Life', 'The Adventures of Tintin', 'The Spy Who Loved Me', 'Inglourious Basterds', 'Indiana Jones and the Kingdom of the Crystal Skull', 'Indiana Jones and the Last Crusade', 'Sphinx']
# ['National Treasure', 'Lara Croft Tomb Raider: The Cradle of Life', 'Lara Croft: Tomb Raider', 'The Adventures of Tintin', 'Indiana Jones and the Temple of Doom', 'Indiana Jones and the Kingdom of the Crystal Skull', 'Indiana Jones and the Last Crusade']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['17 Again', 'Drillbit Taylor']
# Try a different recommendation setting
# ['Pitch Perfect 2', 'Despicable Me', 'Southland Tales', 'The Shaggy Dog', 'Super Troopers', 'Saving Silverman', 'Oceans', 'Transformers: Revenge of the Fallen']
# ['Moms Night Out', 'VeggieTales: The Pirates Who Dont Do Anything', 'American Reunion', 'Mr. Peabody & Sherman', 'Little Miss Sunshine', 'Nanny McPhee and the Big Bang', 'Everybodys Fine', 'Date Night']
# ['Moms Night Out']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Killing Them Softly', 'Romeo Is Bleeding', 'Intolerable Cruelty', 'Ripleys Game', 'War, Inc.', 'Cop Land', 'Mr. & Mrs. Smith', 'Unleashed']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Devils Double', '七人の侍', 'The Wind That Shakes the Barley', 'Michael Collins', 'Lawrence of Arabia', 'Troy', 'Waking Ned', 'Philomena']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Monte Carlo', 'Conspiracy Theory', 'Hotel Rwanda', 'Self/less', 'The Dead Zone', 'A Dangerous Method', 'Simply Irresistible']
# ['Forrest Gump', 'Stir of Echoes', 'Julija in Alfa Romeo', 'The Great Gatsby', 'Death at a Funeral', 'The Bourne Supremacy', 'Conspiracy Theory', 'Anne of Green Gables']
# ['Heavenly Creatures', 'Stir of Echoes', 'Conspiracy Theory', 'Notes on a Scandal', 'Alex & Emma', 'The Postman Always Rings Twice']
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Killing Them Softly', 'Scarface', 'Divergent', 'The Great Gatsby', 'Ella Enchanted', 'Freaky Friday', 'Riding in Cars with Boys']
# ['Mystic River', '12 Angry Men', 'Shaft', 'Anne of Green Gables', 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', 'The Shipping News', 'The Martian', 'High Crimes']
# ['Sleepers', 'Dead Man Walking']
# ['Bad Boys II', 'After Earth', 'Men in Black']
# ['Bad Boys II', 'Men in Black']
# ['Austin Powers: The Spy Who Shagged Me', 'Watchmen', 'Cloverfield', 'Mars Needs Moms', 'Space Chimps', 'Men in Black 3', 'Green Lantern', 'The League of Extraordinary Gentlemen']
# ['Austin Powers: The Spy Who Shagged Me', 'Battle: Los Angeles', 'Alien', 'Men in Black 3', 'Armageddon', 'Terminator Salvation', 'The Terminator', 'E.T. the Extra-Terrestrial']
# ['Austin Powers: The Spy Who Shagged Me', 'Close Encounters of the Third Kind', 'AVP: Alien vs. Predator', 'Men in Black', 'Lifeforce']
# ['The Boxtrolls']
# Try a different recommendation setting
# ['Touching the Void', 'Spider-Man 2', 'American History X', 'Against the Ropes', 'Cinderella Man', 'The Rookie', 'Shes the Man', 'Everybodys Fine']
# ['Like Mike', 'Coach Carter', 'Love & Basketball', 'Juwanna Mann', 'Semi-Pro', 'Hoop Dreams', 'Kita svajonių komanda']
# ['Kita svajonių komanda']
# ['Not Another Teen Movie', 'Racing Stripes', 'Because I Said So']
# ['Something Borrowed', 'Because I Said So']
# ['Paris, je taime', 'Freaky Friday', 'Analyze This', 'Session 9', 'Sex Tape', 'Just Go with It', 'Armageddon', 'Jumping the Broom']
# ['Along Came Polly', '27 Dresses', 'Much Ado About Nothing', 'Bride Wars', 'Good Luck Chuck', 'Freaky Friday', 'Four Weddings and a Funeral', 'سكر بنات']
# ['27 Dresses', 'Four Weddings and a Funeral']
# ['Shes the One', 'The Wedding Date']
# ['Very Bad Things', 'Shes the One', 'The Wedding Date']
# ['Zack and Miri Make a Porno', 'Paris, je taime', 'Spider-Man 2', 'Analyze This', 'Freaky Friday', 'The Last of the Mohicans', 'Armageddon', 'Jumping the Broom']
# ['Closer', 'Everyone Says I Love You', 'August Rush', 'Crossroads', 'Shes the One', '27 Dresses', 'The Story of Us', 'The Wedding Planner']
# ['August Rush', 'Four Weddings and a Funeral', 'The Wedding Planner', 'Down to You', 'Autumn in New York', 'Kate & Leopold']
# ['Midnight in the Garden of Good and Evil', 'Contagion']
# Try a different recommendation setting
# ['Håkon Håkonsen', 'Conspiracy Theory', 'The Wild Bunch', 'But Im a Cheerleader', 'Circumstance', 'Dumb and Dumber To', 'My Super Ex-Girlfriend', 'Prom']
# ['The Immigrant', 'Toy Story', 'Triangle', 'TMNT', 'Sex Drive', 'Top Gun', 'Everyone Says I Love You', 'When Harry Met Sally...']
# ['Transamerica', 'Live and Let Die', 'Everyone Says I Love You', 'Basquiat', 'Meet Dave', 'The Importance of Being Earnest', 'Mambo Italiano', 'Shortbus']
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Avengers', 'Pitch Perfect 2', 'Analyze This', 'Payback', 'Highlander', 'Conspiracy Theory', 'Footloose', 'My Super Ex-Girlfriend']
# ['The Last Waltz', 'Hairspray', 'Once', 'Almost Famous', 'Center Stage', 'Im Not There.', 'Johnny Suede', 'The Blues Brothers']
# ['Johnny Suede', 'Alvin and the Chipmunks']
# ['MacGruber', 'Hackers', 'Beowulf', 'Top Gun', 'The Tourist']
# ['Beowulf']
# ['Lara Croft Tomb Raider: The Cradle of Life', 'Bully', 'The Last Samurai', 'MacGruber', 'The Spy Who Loved Me', 'The Scorpion King', 'One Night with the King', '300']
# ['Agora', 'Platoon']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Casino Royale', 'The Peacemaker', 'Rendition', 'Iron Man 3', 'The Spy Who Loved Me', 'Act of Valor', 'Southland Tales', 'The Hotel New Hampshire']
# ['The Peacemaker', 'G.I. Jane', 'Zero Dark Thirty']
# Try a different recommendation setting
# ['Twister', 'From Dusk Till Dawn']
# Try a different recommendation setting
# ['Austin Powers: The Spy Who Shagged Me', 'The Train', 'The Sorcerers Apprentice', 'Letters from Iwo Jima', 'Act of Valor', 'Das Boot', 'Spy Kids 3-D: Game Over', 'The Hunt for Red October']
# ['1941', 'Breakdown', 'Das Boot', 'K-19: The Widowmaker']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Jaws: The Revenge', 'Harry Potter and the Order of the Phoenix', 'Letters from Iwo Jima', 'Romeo Is Bleeding', 'Brother', 'Shaft', 'Underclassman', 'Jack Reacher']
# ['一個好人', 'Se7en', 'First Blood', 'Margaret', 'One Missed Call', 'Disturbing Behavior', 'Open Road', 'Dredd']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Austin Powers: The Spy Who Shagged Me', 'Dawn of the Dead', 'Big Fat Liar', 'Trade', 'Are We There Yet?', 'Eastern Promises', 'Vantage Point', 'Austin Powers in Goldmember']
# ['Austin Powers: The Spy Who Shagged Me', 'Transporter 2', 'Austin Powers in Goldmember', 'Cars', 'The Fast and the Furious: Tokyo Drift']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Repo Men', 'Southland Tales', 'Conspiracy Theory', 'Lone Star', 'The Dead Zone', 'Super Troopers', 'My Super Ex-Girlfriend', 'I Hope They Serve Beer in Hell']
# ['Austin Powers: The Spy Who Shagged Me', 'Pirates of the Caribbean: The Curse of the Black Pearl', 'Force 10 from Navarone', 'The Avengers', 'Lake Placid', 'My Bloody Valentine', 'The Spy Who Loved Me', 'The BFG']
# ['From Russia with Love', 'The Spy Who Loved Me', 'Mission: Impossible', 'On Her Majestys Secret Service', 'The Man with the Golden Gun', 'Tomorrow Never Dies', 'American Gangster', 'For Your Eyes Only']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Killing Them Softly', 'Sin City: A Dame to Kill For', 'The Duchess', 'Glitter', 'In Cold Blood', 'Walter', 'Southland Tales', 'Fatal Attraction']
# ['Jindabyne', 'The Talented Mr. Ripley', 'Beyond the Lights']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Austin Powers: The Spy Who Shagged Me', 'The Vow', 'Army of Darkness', 'Men in Black 3', 'The Bourne Supremacy', 'Southland Tales', 'Lost in Space', 'Just Visiting']
# ['Before I Go to Sleep', 'Jason Bourne', 'The Bourne Identity', 'Southland Tales', 'Memento']
# Try a different recommendation setting
# ['辛亥革命']
# ['辛亥革命']
# ['Secretary', 'Riding in Cars with Boys', 'Brother', 'Lights Out', 'Dead Like Me: Life After Death', 'The Wolverine', 'Southland Tales', 'Charlie and the Chocolate Factory']
# ['Magnolia', 'Shutter', 'The Last Samurai', 'The Awakening', 'Kundun', '1408', 'The Rage: Carrie 2', 'Disturbing Behavior']
# ['The Last Samurai']
# ['In the Heart of the Sea']
# Try a different recommendation setting
# ['Sin City: A Dame to Kill For', 'City of Ember', 'Divergent', 'Dawn of the Planet of the Apes', 'Repo Men', 'The Bourne Supremacy', 'Highlander', 'Pitch Black']
# ['Children of Men', 'Maze Runner: The Scorch Trials', 'Salt', 'Interstellar', 'Fortress', 'The Host', 'Babylon A.D.', 'Autómata']
# ['Mad Max: Fury Road', 'Frequency']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Paranormal Activity 2', 'Deliver Us from Evil', 'The Vatican Tapes', 'The Devil Inside', 'On The Downlow', 'The Skeleton Key', 'Paranormal Activity', 'Hellboy']
# ['The Evil Dead', 'Deliver Us from Evil', 'End of Days']
# Try a different recommendation setting
# ['Lara Croft: Tomb Raider']
# Try a different recommendation setting
# ['The Train', 'Austin Powers: The Spy Who Shagged Me', 'Watchmen', 'The Sorcerers Apprentice', 'Safe House', 'Paris, je taime', 'Rendition', 'Harriet the Spy']
# ['Austin Powers: The Spy Who Shagged Me', 'Spy Game', 'Rendition', 'The Spy Who Loved Me', 'Salt', 'Southland Tales', 'Beyond Borders', 'Spectre']
# ['Austin Powers: The Spy Who Shagged Me', 'The Spy Who Loved Me', 'On Her Majestys Secret Service', 'True Lies', 'RED 2', 'Jack Ryan: Shadow Recruit', 'Salt', 'Central Intelligence']
# ['Charly']
# Try a different recommendation setting
# ['Desert Dancer', 'Dougs 1st Movie', 'Footloose', 'Go for It!', 'Crossroads', 'Take the Lead', 'Fish Tank', 'Mary Poppins']
# ['Step Up', 'Dancer in the Dark', 'Footloose', 'Honey']
# Try a different recommendation setting
# ['A Prairie Home Companion', 'What Just Happened']
# ['The Hunger Games: Mockingjay - Part 1', 'Meet the Parents', 'Brazil']
# ['Austin Powers: The Spy Who Shagged Me', 'Safe House', 'Rendition', 'American History X', 'Shooter', 'Conspiracy Theory', 'Fatal Attraction', 'Primary Colors']
# ['Austin Powers: The Spy Who Shagged Me', 'Diner', 'Mr. Smith Goes to Washington', 'The Last Samurai', 'Antz', 'Rendition', 'Conspiracy Theory', 'The Manchurian Candidate']
# ['Nixon', 'Rambo: First Blood Part II', 'Rendition', 'Primary Colors', 'Fahrenheit 9/11', 'Absolute Power', 'Head of State', 'Clear and Present Danger']
# ['Parental Guidance']
# Try a different recommendation setting
# ['Under the Tuscan Sun', 'Out of Time', 'Intolerable Cruelty', 'The Last Five Years', 'Bad Moms', 'Opposite Sex', 'Young Adult', 'Everyone Says I Love You']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Patch Adams', 'The Boat That Rocked', 'Confessions of a Dangerous Mind', 'Flawless', 'Next Stop Wonderland']
# ['Mission: Impossible III']
# ['Austin Powers: The Spy Who Shagged Me', 'Safe House', 'Cloverfield', 'Rendition', 'Bad Moms', 'Conspiracy Theory', 'Hotel Rwanda', 'Cant Hardly Wait']
# ['Wag the Dog', 'Topaz', 'Live Free or Die Hard', 'Spy Game', 'The Sum of All Fears', 'xXx', 'Bridge of Spies', 'The Hunt for Red October']
# Try a different recommendation setting
# ['Purple Violets', 'Punch-Drunk Love', 'The Switch', 'Hes Just Not That Into You', 'Just Go with It', 'The Break-Up']
# ['Just Go with It', 'The Break-Up']
# ['Jaws: The Revenge', 'Freaky Friday', 'Act of Valor', 'Brother', 'American History X', 'Session 9', 'Southland Tales', 'Just Go with It']
# ['27 Dresses', 'A Lot Like Love', 'The Ugly Truth', 'The Holiday', 'The Boy Next Door', 'Everyone Says I Love You', 'License to Wed', 'Beverly Hills Cop']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Zack and Miri Make a Porno', 'Spider-Man 2', 'Analyze This', 'Freaky Friday', 'Armageddon', 'Star Trek IV: The Voyage Home', 'Jumping the Broom', 'The Story of Us']
# ['The Story of Us', '27 Dresses', 'Four Weddings and a Funeral', 'The Five-Year Engagement', 'My Best Friends Wedding', 'Leap Year', 'Shes the One']
# ['Four Weddings and a Funeral', 'My Best Friends Wedding']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Cloverfield', 'Mars Needs Moms', 'Men in Black 3', 'Green Lantern', 'Armageddon', 'Galaxina', 'Transformers', 'Alien³']
# ['Red Planet', 'Alien', 'Star Trek Into Darkness', 'Interstellar', 'Galaxina', 'Aliens', 'The Astronauts Wife', 'Alien³']
# ['Alien³', 'John Carter', 'Zathura: A Space Adventure', 'The Day the Earth Stood Still']
# Try a different recommendation setting
# Try a different recommendation setting
# ['Zack and Miri Make a Porno', 'Home Alone', 'Southland Tales', 'Born on the Fourth of July', 'Diary of a Wimpy Kid: Dog Days', 'We Are Marshall', 'The Skeleton Twins', 'Things We Lost in the Fire']
# ['The Sixth Sense', 'Lions for Lambs', 'Shrek the Third', 'Nothing']
# Try a different recommendation setting
# Try a different recommendation setting
# Try a different recommendation setting
# ['Cloverfield', 'Mars Needs Moms', 'Men in Black 3', 'Green Lantern', 'Galaxina', 'Transformers', 'Alien³', 'The Island of Dr. Moreau']
# ['Aliens', 'Alien', 'Alien³', 'Predator', 'Predators', 'Alien: Resurrection', 'AVP: Alien vs. Predator']
# ['AVP: Alien vs. Predator']
# ['Shopgirl', 'Me and Orson Welles', 'Moulin Rouge!']
# Try a different recommendation setting
# ['Moulin Rouge!', 'Gullivers Travels', 'Shopgirl', 'Hancock', 'Closer', 'Beastly', 'August Rush', 'Hamlet']
# ['Pocahontas', '10 Things I Hate About You', 'West Side Story', 'The Great Gatsby']
# Try a different recommendation setting
# ['Star Trek: First Contact', 'Star Trek: Nemesis', 'Star Trek: Insurrection']
# Try a different recommendation setting
# ['Shutter', 'Red Dog', 'Julija in Alfa Romeo', 'Spider-Man 2', 'The Lazarus Effect', 'Random Hearts', 'Thunderbirds', 'Another Earth']
# Try a different recommendation setting
# Try a different recommendation setting
# ['First Blood', 'Rambo: First Blood Part II']
# ['First Blood', 'Rambo: First Blood Part II']
# ['Lo imposible', 'Southland Tales', 'Spy Kids 3-D: Game Over', 'Public Enemies', 'The Hunt for Red October', 'The Equalizer', '3000 Miles to Graceland', 'Shrek 2']
# ['The Living Daylights', 'Rambo: First Blood Part II', 'Child 44']
# ['Rambo: First Blood Part II']
# Try a different recommendation setting
# Try a different recommendation setting
# ['The Butterfly Effect', 'Holes', 'The Vow', 'Vanilla Sky', 'The Bourne Supremacy', 'Southland Tales', 'Don Juan DeMarco', 'Dark Shadows']
# ['Don Juan DeMarco', 'K-PAX']
# Try a different recommendation setting
#
# {'precision': 0.5054945054945055, 'recall': 0.6388888888888888, 'f1': 0.5644171779141104}
